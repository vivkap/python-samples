# %%
def ratio(revenue, expenses):
    profit = revenue - expenses
    profit_percent = profit/revenue
    return {"profit":profit, "profit_percent":profit_percent}

# %%
ratio(2000,1900)
# Out:
# {'profit': 100, 'profit_percent': 0.05}

# %%
L = [5,6,7,8]

# %%
Lsqr = list(map(lambda x: x**3, L))

# %%
Lsqr
# Out:
# [125, 216, 343, 512]

# %%
strList = ['hello', 'to','the','world','of','python','programming']

# %%
uppStrList = list(map(lambda x: str.upper(x), strList))

# %%
('-').join(uppStrList)
# Out:
# 'HELLO-TO-THE-WORLD-OF-PYTHON-PROGRAMMING'

# %%
('-').join(uppStrList).center(90,'*')
# Out:
# '*************************HELLO-TO-THE-WORLD-OF-PYTHON-PROGRAMMING*************************'

# %%
list(filter(lambda x: (x>340) & (x<500), Lsqr))
# Out:
# [343]

# %%
### Using dfply package for dataframes analysis and processing

# %%
# !pip install dfply
# Out:
# ...
#      |████████████████████████████████| 612 kB 1.7 MB/s eta 0:00:01    |██▊                             | 51 kB 1.7 MB/s eta 0:00:01     |███████████████████████████▉    | 532 kB 1.7 MB/s eta 0:00:01
# ...

# %%
from dfply import *
import pandas as pd

# %%
import os
os.chdir('./DataScience with Python Master/Basics')
# Out:
# FileNotFoundErrorTraceback (most recent call last)
# <ipython-input-66-c56a83ed7932> in <module>
#       1 import os
# ----> 2 os.chdir('./DataScience with Python Master/Basics')
#
# FileNotFoundError: [Errno 2] No such file or directory: './DataScience with Python Master/Basics'

# %%
df = pd.read_csv('tips.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
df[['sex','smoker','time']]
# Out:
#         sex smoker    time
# 0    Female     No  Dinner
# 1      Male     No  Dinner
# 2      Male     No  Dinner
# 3      Male     No  Dinner
# 4    Female     No  Dinner
# ..      ...    ...     ...
# 239    Male     No  Dinner
# 240  Female    Yes  Dinner
# 241    Male    Yes  Dinner
# 242    Male     No  Dinner
# 243  Female     No  Dinner
#
# [244 rows x 3 columns]

# %%
df>>select(X.total_bill, X.tip)>>head()
# Out:
#    total_bill   tip
# 0       16.99  1.01
# 1       10.34  1.66
# 2       21.01  3.50
# 3       23.68  3.31
# 4       24.59  3.61

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['Actual_bill'] = df['total_bill'] - df['tip']

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  Actual_bill
# 0         16.99  1.01  Female     No   Sun  Dinner     2        15.98
# 1         10.34  1.66    Male     No   Sun  Dinner     3         8.68
# 2         21.01  3.50    Male     No   Sun  Dinner     3        17.51
# 3         23.68  3.31    Male     No   Sun  Dinner     2        20.37
# 4         24.59  3.61  Female     No   Sun  Dinner     4        20.98
# ..          ...   ...     ...    ...   ...     ...   ...          ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3        23.11
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2        25.18
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2        20.67
# 242       17.82  1.75    Male     No   Sat  Dinner     2        16.07
# 243       18.78  3.00  Female     No  Thur  Dinner     2        15.78
#
# [244 rows x 8 columns]

# %%
len(df[(df['total_bill'] < 16) & (df['day'] == 'Sun')])
# Out:
# 22

# %%
### File Operations

# %%
import os
os.getcwd()
# Out:
# '/home/jovyan'

# %%
with open('log.txt','rb') as fh:
    #fh.seek(10)
    linesList = fh.readlines()
    #linesList = fh.read(25)
    fh.close()
print(type(linesList))  
print(linesList)
# Out:
# <class 'list'>
# [b'HardID:usb\\vid_1f3a&pid_efe8\n', b'\r\n', b'DeviceID:USB\\ROOT_HUB20&VID8086&PID1C26&REV0004\n', b'\r\n', b'DeviceID:USB\\ROOT_HUB20&VID8086&PID1C2D&REV0004\n', b'\r\n', b'DeviceID:USB\\VID_046D&PID_C52E&REV_1500\n', b'\r\n', b'DeviceID:USB\\VID_046D&PID_C52E&REV_1500&MI_00\n', b'\r\n', b'DeviceID:USB\\VID_046D&PID_C52E&REV_1500&MI_01\n', b'\r\n', b'DeviceID:USB\\VID_064E&PID_D20C&REV_0111\n', b'\r\n', b'DeviceID:USB\\VID_064E&PID_D20C&REV_0111&MI_00\n', b'\r\n', b'DeviceID:USB\\VID_8087&PID_0024&REV_0000\n', b'\r\n', b'DeviceID:USB\\VID_8087&PID_0024&REV_0000\n', b'\r\n', b'open file fail:o\xd9\n', b'\r\n', b'2015-Dec-30 16:33:38: Service stopped.\r\n']

# %%
for line in linesList:
    #print(line)
    print(str(line).replace('b\'','').replace('\\r','').replace('\\n\'',''))
# Out:
# HardID:usb\\vid_1f3a&pid_efe8
#
# DeviceID:USB\\ROOT_HUB20&VID8086&PID1C26&REV0004
#
# DeviceID:USB\\ROOT_HUB20&VID8086&PID1C2D&REV0004
#
# DeviceID:USB\\VID_046D&PID_C52E&REV_1500
#
# DeviceID:USB\\VID_046D&PID_C52E&REV_1500&MI_00
#
# DeviceID:USB\\VID_046D&PID_C52E&REV_1500&MI_01
#
# DeviceID:USB\\VID_064E&PID_D20C&REV_0111
#
# DeviceID:USB\\VID_064E&PID_D20C&REV_0111&MI_00
#
# DeviceID:USB\\VID_8087&PID_0024&REV_0000
#
# DeviceID:USB\\VID_8087&PID_0024&REV_0000
#
# open file fail:o\xd9
#
# 2015-Dec-30 16:33:38: Service stopped.

# %% [markdown]
# ### Exception  Handling

# %% [markdown]
# ### Regular Expressions

# %%
import re

# %%
sentence = " Hi. This is an introduction to regular expressions. are you ready for this"

# %%
L = re.finditer('ar',sentence)

# %%
type(L)
# Out:
# callable_iterator

# %%
for i in L:
    print(i.span())
    print(str(i))

# %%
 re.sub('[aA]r','AR',sentence)
# Out:
# ' Hi. This is an introduction to regulAR expressions. ARe you ready for this'

# %% [markdown]
# ### Web Scraping

# %%
import urllib.request

# %%
url = "https://stackoverflow.com/search?q=open+in+python+loop"

# %%
response = urllib.request.urlopen(url)

# %%
htmlbody = response.readlines()

# %%
type(htmlbody)
# Out:
# list

# %%
for htmlline in  htmlbody:
    #print(type(htmlline))
    print(htmlline.decode())
    #print(str(htmlline))
# Out:
# <!DOCTYPE html>
#
#
#
#
#
#     <html class="html__responsive">
#
#
#
#     <head>
#
#
#
#         <title>Human verification - Stack Overflow</title>
#
#         <link rel="shortcut icon" href="https://cdn.sstatic.net/Sites/stackoverflow/img/favicon.ico?v=4f32ecc8f43d">
#
#         <link rel="apple-touch-icon" href="https://cdn.sstatic.net/Sites/stackoverflow/img/apple-touch-icon.png?v=c78bd457575a">
#
#         <link rel="image_src" href="https://cdn.sstatic.net/Sites/stackoverflow/img/apple-touch-icon.png?v=c78bd457575a">
#
#         <link rel="search" type="application/opensearchdescription+xml" title="Stack Overflow" href="/opensearch.xml">
#
#         <meta name="viewport" content="width=device-width, height=device-height, initial-scale=1.0, minimum-scale=1.0">
#
#         <meta property="og:type" content= "website" />
#
#         <meta property="og:url" content="https://stackoverflow.com/nocaptcha?s=4154f4e1-6029-4abe-bfef-6d3a04bf2f7f"/>
#
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(htmlbody)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 774 entries, 0 to 773
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       774 non-null    object
# dtypes: object(1)
# memory usage: 6.2+ KB

# %%
os.getcwd()
# Out:
# '/home/jovyan'

# %%
df.to_csv('stackflow.csv')

# %% [markdown]
# #### OOPS concept
